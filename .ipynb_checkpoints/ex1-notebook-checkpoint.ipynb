# %%
import pandas as pd

# %%
data = pd.read_csv('machine.data',names=['vendor','model','MYCT','MMIN','MMAX','CACH','CHMIN','CHMAX','PRP','ERP'])
label = data['ERP']
data = data.drop(columns=['ERP'])

# %%
# data = pd.read_csv('forestfires.csv')
# label = data['area']
# data = data.drop(columns=['area'])

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split
# data = data[['MMIN','MMAX','CACH','CHMIN','CHMAX','PRP']] ## Only numeric attributes
X_train, X_test, y_train, y_test = train_test_split(data, label, test_size=0.33)

# %%
all_cols = pd.get_dummies(data).columns
def add_missing_dummy_columns( d, columns ):
    missing_cols = set( columns ) - set( d.columns )
    for c in missing_cols:
        d[c] = 0

def fix_columns( d, columns ):  
    add_missing_dummy_columns( d, columns )

    # make sure we have all the columns we need
    assert( set( columns ) - set( d.columns ) == set())

    d = d[ columns ]
    return d

# %%
def create_node(samples, labels, depth, model=None, split_by_feature=None, threshold=None, loss=None, 
                childrens=[], nominal_value=None):
    if model==None:
        loss, model = linear_fit(samples,labels)
    return {
        'samples': samples,
        'labels': labels,
        'childrens': childrens,
        'model': model, 
        'loss': loss,
        'split_by_feature': split_by_feature,
        'threshold': threshold,
        'nominal_value':nominal_value,
        'depth':depth
    }

# %%
from sklearn.model_selection import train_test_split

def linear_fit(train, label):
    reg = Ridge().fit(pd.get_dummies(train), label)
    mse_score = mean_squared_error(reg.predict(pd.get_dummies(train)), label)
    wmse_score = mse_score*len(train)
    return wmse_score, reg

# %%
min_samples_leaf=2
def numeric_split(feature, train, label, threshold, depth):
    mask = train[feature] >= threshold
    right_node_samples, right_node_labels = train[mask], label[mask]
    left_node_samples, left_node_labels = train[~mask], label[~mask]
    if len(left_node_samples)<min_samples_leaf or len(right_node_samples)<min_samples_leaf:
        return {'childrens':[],'loss':None}
    right_node_wmse, right_node_model = linear_fit(right_node_samples, right_node_labels)
    left_node_wmse, left_node_model = linear_fit(left_node_samples, left_node_labels)
    wmse = (right_node_wmse + left_node_wmse)/len(train)
    mse, model = linear_fit(train,label)
    right_node = create_node(right_node_samples, right_node_labels, depth, right_node_model, loss=right_node_wmse)
    left_node = create_node(left_node_samples, left_node_labels, depth, left_node_model, loss=left_node_wmse)
    
    return create_node(train, label, depth, model ,loss=wmse, childrens=[right_node, left_node], split_by_feature=feature, threshold=threshold)

# %%
def node_from_nominal_group(df, depth, nominal_value):
    samples = df.drop('Y',axis=1)
    labels = df['Y']
    node = create_node(samples, labels, depth, nominal_value=nominal_value)
    print(node['nominal_value'])
    return node

def nominal_split(feature, train, label, depth):
    df = train.copy()
    df['Y'] = label
    filtered_nominal_groups = df.groupby(feature).filter(lambda x: len(x)>=min_samples_leaf).groupby(feature)
    if len(filtered_nominal_groups)<2:
        return None
    
    nodes = []
    wmse = 0
    for nominal_value, nominal_group in filtered_nominal_groups:
        node = node_from_nominal_group(nominal_group, depth, nominal_value)
        nodes.append(node)
        wmse += node['loss']
    
    mse, model = linear_fit(train, label) # We don't use the MSE of the linear_fit, but we train a model in order to use it 
                                          # at prediction, when the nominal feature value won't be one of the splitted values
    print(wmse, len(train), len(filtered_nominal_groups))
    wmse = wmse/len(train) 
    return create_node(train, label, depth, model ,loss=wmse, split_by_feature=feature, childrens=nodes)

# %%
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import Ridge
from operator import itemgetter

def split_by_mse(feature, node):
    if node['samples'][feature].dtype=='O':
        split = nominal_split(feature, node['samples'], node['labels'], node['depth']+1)
        if split==None or len(split['childrens'])<2:
            return None
    else:       
        attr_splits = list(set(node['samples'][feature].values))
        splits = []
        for split in attr_splits:
            split_childrens = numeric_split(feature, node['samples'], node['labels'], split, node['depth']+1)
            if len(split_childrens['childrens']) > 0 and all(children['loss'] is not None for children in split_childrens['childrens']):
                splits.append(split_childrens)
        if len(splits)==0:
            return None
        split = min(splits,key=itemgetter('loss'))
        # We filter None due to splits with low number of samples in one of the sides
        if node['nominal_value']!=None:
            split['nominal_value'] = node['nominal_value'] #Important to keep the nominal_value in case we splitted a categorical node
    return split

# %%
def split_node(node):
    features = node['samples'].columns
    splits = []
    for feature in features:
        split = split_by_mse(feature, node)
        if split!=None:
            splits.append(split)
    if len(splits)==0:
        return node
    curr_split = min(splits, key=itemgetter('loss'))
    return curr_split

# %%
tree_root = create_node(X_train, y_train,depth=0)

def expand_tree(node):
    node = split_node(node)
    if len(node['childrens'])==0:
        return node
    print("Splitted node at depth {d} by feature {f} and threshold {t}".format(d=node['depth'],f=node['split_by_feature'],t=node['threshold']))
    for index, children in enumerate(node['childrens']):
        print("Node {i} with {n} samples".format(i=index,n=len(children['samples'])))
        node['childrens'][index] = expand_tree(children)
        
    return node

# %%
tree = expand_tree(tree_root)
# Out:
# amdahl
# burroughs
# c.r.d
# cambex
# cdc
# dec
# dg
# formation
# gould
# harris
# honeywell
# hp
# ibm
# ipl
# magnuson
# nas
# ncr
# nixdorf
# perkin-elmer
# prime
# siemens
# sperry
# 586.3310876038586 140 22
# vendor 4.188079197170419
# MYCT 92.83529131014546
# MMIN 28.390570322683747
# MMAX 24.147559255176215
# CACH 60.5846697151198
# CHMIN 57.97721153656021
# CHMAX 75.24648196053013
# PRP 18.44466360499979
# Splitted node at depth 1 by feature vendor and threshold None
# Node 0 with 5 samples
# MYCT 1.2337622246007717e-12
# MMIN 1.2337622246007717e-12
# MMAX 4.235940962254747e-11
# CACH 1.2337622246007717e-12
# CHMIN 1.2337622246007717e-12
# PRP 1.2337622246007717e-12
# Splitted node at depth 2 by feature MYCT and threshold 29
# Node 0 with 2 samples
# Node 1 with 3 samples
# Node 1 with 6 samples
# MMIN 2.193936740908015e-11
# MMAX 2.193936740908015e-11
# CHMIN 3.232085773878445e-11
# CHMAX 5.14195175939164e-11
# PRP 1.978533144988714e-11
# Splitted node at depth 2 by feature PRP and threshold 31
# Node 0 with 3 samples
# Node 1 with 3 samples
# Node 2 with 5 samples
# MMIN 4.192745336318189e-13
# MMAX 3.5114275810977675e-13
# CACH 1.1941210206422136e-10
# CHMAX 3.5114275810977675e-13
# PRP 4.192745336318189e-13
# Splitted node at depth 2 by feature MMAX and threshold 5000
# Node 0 with 3 samples
# Node 1 with 2 samples
# Node 3 with 3 samples
# Node 4 with 8 samples
# MYCT 0.02763398048910346
# MMIN 7.583630378324102e-05
# MMAX 7.583630378324102e-05
# CACH 0.00043669962763961956
# CHMIN 0.00043669962763961956
# CHMAX 0.00043669962763961956
# PRP 0.0004243189315811673
# Splitted node at depth 2 by feature MMIN and threshold 2000
# Node 0 with 4 samples
# MYCT 1.8248262176992107e-08
# MMIN 1.8248262176992107e-08
# MMAX 1.8248262176992107e-08
# PRP 1.8248262176992107e-08
# Splitted node at depth 3 by feature MYCT and threshold 56
# Node 0 with 2 samples
# Node 1 with 2 samples
# Node 1 with 4 samples
# MYCT 9.96499463848608e-13
# MMIN 9.96499463848608e-13
# CACH 9.96499463848608e-13
# CHMIN 9.96499463848608e-13
# CHMAX 9.96499463848608e-13
# PRP 9.96499463848608e-13
# Splitted node at depth 3 by feature MYCT and threshold 50
# Node 0 with 2 samples
# Node 1 with 2 samples
# Node 5 with 4 samples
# MYCT 7.671607823567758e-11
# MMIN 8.993848029188585e-09
# CACH 7.671607823567758e-11
# CHMAX 7.671607823567758e-11
# PRP 7.671607823567758e-11
# Splitted node at depth 2 by feature MYCT and threshold 320
# Node 0 with 2 samples
# Node 1 with 2 samples
# Node 6 with 6 samples
# MYCT 9.958599234065555e-08
# MMIN 8.916446412771466e-07
# MMAX 1.9433511761182376e-08
# CACH 8.916446412771466e-07
# CHMAX 8.916446412771466e-07
# PRP 5.302827128722965e-09
# Splitted node at depth 2 by feature PRP and threshold 60
# Node 0 with 3 samples
# Node 1 with 3 samples
# Node 7 with 2 samples
# Node 8 with 2 samples
# Node 9 with 3 samples
# Node 10 with 8 samples
# MYCT 0.015037746469990962
# MMIN 0.015037746469990962
# MMAX 4.2660772685326416e-05
# CACH 4.2660772685326416e-05
# CHMIN 0.00018731520472379309
# CHMAX 0.0001873049645179168
# PRP 4.068902143400168e-05
# Splitted node at depth 2 by feature PRP and threshold 35
# Node 0 with 4 samples
# MMAX 1.027737246298337e-06
# CHMAX 3.980510629083485e-14
# PRP 1.027737246298337e-06
# Splitted node at depth 3 by feature CHMAX and threshold 54
# Node 0 with 2 samples
# Node 1 with 2 samples
# Node 1 with 4 samples
# MYCT 7.961070444033254e-05
# MMIN 7.961070444033254e-05
# CHMIN 7.029830726434574e-12
# Splitted node at depth 3 by feature CHMIN and threshold 3
# Node 0 with 2 samples
# Node 1 with 2 samples
# Node 11 with 5 samples
# MMIN 1.500141923612264e-12
# MMAX 8.554758246301508e-12
# CACH 1.500141923612264e-12
# CHMAX 6.712828636758313e-10
# PRP 8.554758246301508e-12
# Splitted node at depth 2 by feature MMIN and threshold 2000
# Node 0 with 2 samples
# Node 1 with 3 samples
# Node 12 with 24 samples
# MYCT 0.2152911358756098
# MMIN 0.25777672969848864
# MMAX 0.0669940505678309
# CACH 0.8578525673084268
# CHMIN 0.33793801808179186
# CHMAX 0.33793801808179186
# PRP 0.07249180526117967
# Splitted node at depth 2 by feature MMAX and threshold 12000
# Node 0 with 9 samples
# MYCT 0.005676323653315833
# MMIN 0.0069782785384257485
# MMAX 0.0110674929654572
# CACH 0.005805726434008766
# CHMIN 0.0060545809877604615
# CHMAX 0.0069782785384257485
# PRP 0.006127127128964953
# Splitted node at depth 3 by feature MYCT and threshold 57
# Node 0 with 4 samples
# MYCT 9.664643771626189e-13
# MMIN 9.664643771626189e-13
# CHMIN 9.664643771626189e-13
# CHMAX 9.664643771626189e-13
# PRP 9.664643771626189e-13
# Splitted node at depth 4 by feature MYCT and threshold 180
# Node 0 with 2 samples
# Node 1 with 2 samples
# Node 1 with 5 samples
# MYCT 0.010576979490735237
# MMIN 0.010576958766177421
# MMAX 0.010576958766177421
# CACH 0.010467063875812586
# CHMIN 0.010576958766177421
# CHMAX 0.010576958766177421
# PRP 0.010576958766177421
# Splitted node at depth 4 by feature CACH and threshold 16
# Node 0 with 3 samples
# Node 1 with 2 samples
# Node 1 with 15 samples
# MYCT 0.0027887301001517832
# MMIN 0.003210564722262051
# MMAX 0.0028543902107169288
# CACH 0.0032473637337852666
# CHMIN 0.013827993621158994
# CHMAX 0.0027887301001517832
# PRP 0.0032473637337852666
# Splitted node at depth 3 by feature MYCT and threshold 400
# Node 0 with 9 samples
# MYCT 0.00017576120394507873
# MMIN 6.404994352266008e-11
# MMAX 1.4926454871307508e-11
# CHMIN 0.0002696832551062195
# CHMAX 8.046875441485685e-05
# PRP 1.4926454871307508e-11
# Splitted node at depth 4 by feature MMAX and threshold 2000
# Node 0 with 5 samples
# MYCT 1.5976312801038412e-12
# MMIN 1.0236445605884368e-12
# MMAX 1.0236445605884368e-12
# CHMIN 8.578063377019111e-13
# CHMAX 8.578063377019111e-13
# PRP 1.4755865856270638e-12
# Splitted node at depth 5 by feature CHMIN and threshold 1
# Node 0 with 3 samples
# Node 1 with 2 samples
# Node 1 with 4 samples
# MYCT 8.816092277435847e-12
# MMIN 5.944442260245709e-12
# CHMAX 8.816092277435847e-12
# Splitted node at depth 5 by feature MMIN and threshold 768
# Node 0 with 2 samples
# Node 1 with 2 samples
# Node 1 with 6 samples
# MYCT 3.679321613329477e-11
# MMIN 2.2577684530620006e-10
# MMAX 3.679321613329477e-11
# CACH 1.2533992895486326e-12
# CHMIN 3.8079481026515524e-11
# PRP 1.2533992895486326e-12
# Splitted node at depth 4 by feature CACH and threshold 8
# Node 0 with 4 samples
# MYCT 6.335780360058864e-13
# MMAX 6.335780360058864e-13
# CHMIN 6.335780360058864e-13
# PRP 6.335780360058864e-13
# Splitted node at depth 5 by feature MYCT and threshold 225
# Node 0 with 2 samples
# Node 1 with 2 samples
# Node 1 with 2 samples
# Node 13 with 2 samples
# Node 14 with 4 samples
# MYCT 0.0
# MMIN 0.0
# MMAX 0.0
# CHMIN 0.0
# CHMAX 0.0
# PRP 0.0
# Splitted node at depth 2 by feature MYCT and threshold 100
# Node 0 with 2 samples
# Node 1 with 2 samples
# Node 15 with 13 samples
# MYCT 0.0061526486797122
# MMIN 0.7394508511113483
# MMAX 0.06312740538545045
# CACH 0.014039205102008307
# CHMIN 0.0069904261745329845
# CHMAX 0.0069904261745329845
# PRP 0.0061526486797122
# Splitted node at depth 2 by feature MYCT and threshold 50
# Node 0 with 8 samples
# MYCT 8.640070402684221e-05
# MMIN 0.002670864153899008
# MMAX 0.002404413570903827
# CACH 8.736304805229314e-05
# CHMIN 2.5953856084293004e-05
# CHMAX 2.5953856084293004e-05
# PRP 8.640070402684221e-05
# Splitted node at depth 3 by feature CHMIN and threshold 5
# Node 0 with 4 samples
# MYCT 5.057169267673754e-12
# MMIN 2.062498654321559e-07
# CHMIN 5.057169267673754e-12
# CHMAX 2.062498654321559e-07
# PRP 2.062498654321559e-07
# Splitted node at depth 4 by feature MYCT and threshold 72
# Node 0 with 2 samples
# Node 1 with 2 samples
# Node 1 with 4 samples
# MYCT 5.170927922406523e-05
# MMIN 5.170927922406523e-05
# MMAX 5.170927922406523e-05
# CACH 5.170927922406523e-05
# PRP 5.170927922406523e-05
# Splitted node at depth 4 by feature MYCT and threshold 92
# Node 0 with 2 samples
# Node 1 with 2 samples
# Node 1 with 5 samples
# MYCT 1.3302011965874562e-11
# MMAX 8.126291335168711e-08
# CACH 8.126291335168711e-08
# PRP 1.3302011965874562e-11
# Splitted node at depth 3 by feature MYCT and threshold 40
# Node 0 with 3 samples
# Node 1 with 2 samples
# Node 16 with 11 samples
# MYCT 0.0483580403030546
# MMIN 0.00588528712405482
# MMAX 0.001544196239088709
# CACH 0.0483580403030546
# CHMIN 0.0483580403030546
# CHMAX 0.049927188005731746
# PRP 0.001630544278947251
# Splitted node at depth 2 by feature MMAX and threshold 12000
# Node 0 with 5 samples
# MYCT 8.47519853826977e-12
# MMIN 2.4693301208361247e-06
# CACH 5.712338606489243e-12
# CHMIN 8.47519853826977e-12
# PRP 5.712338606489243e-12
# Splitted node at depth 3 by feature CACH and threshold 128
# Node 0 with 2 samples
# Node 1 with 3 samples
# Node 1 with 6 samples
# MMIN 4.605360992772221e-06
# MMAX 4.605360992772221e-06
# CHMAX 4.605360992772221e-06
# PRP 4.605360992772221e-06
# Splitted node at depth 3 by feature MMIN and threshold 2000
# Node 0 with 4 samples
# MMIN 6.90980060260487e-06
# PRP 6.90980060260487e-06
# Splitted node at depth 4 by feature MMIN and threshold 4000
# Node 0 with 2 samples
# Node 1 with 2 samples
# Node 1 with 2 samples
# Node 17 with 3 samples
# Node 18 with 2 samples
# Node 19 with 2 samples
# Node 20 with 9 samples
# MYCT 0.00024375368224591052
# MMIN 9.361237711583387e-05
# MMAX 9.61545988221473e-05
# CACH 0.0008966385168270466
# CHMIN 9.361237711583387e-05
# CHMAX 3.679342127978571e-05
# PRP 9.361237711583387e-05
# Splitted node at depth 2 by feature CHMAX and threshold 16
# Node 0 with 4 samples
# MYCT 5.139698986220612e-12
# MMAX 5.139698986220612e-12
# CACH 4.918043452512151e-13
# CHMIN 4.918043452512151e-13
# CHMAX 4.918043452512151e-13
# PRP 4.918043452512151e-13
# Splitted node at depth 3 by feature CACH and threshold 64
# Node 0 with 2 samples
# Node 1 with 2 samples
# Node 1 with 5 samples
# MYCT 9.059589271680668e-13
# MMIN 9.059589271680668e-13
# MMAX 9.059589271680668e-13
# CACH 9.059589271680668e-13
# CHMIN 1.4734844465461996e-11
# CHMAX 1.4734844465461996e-11
# PRP 9.059589271680668e-13
# Splitted node at depth 3 by feature MYCT and threshold 105
# Node 0 with 3 samples
# Node 1 with 2 samples
# Node 21 with 7 samples
# MYCT 1.2470250839534754e-05
# MMIN 1.2765904988933479e-05
# MMAX 1.2470250839534754e-05
# CACH 4.18837646296918e-11
# CHMIN 1.2470250839534754e-05
# CHMAX 4.18837646296918e-11
# PRP 4.18837646296918e-11
# Splitted node at depth 2 by feature CACH and threshold 112
# Node 0 with 3 samples
# Node 1 with 4 samples
# MYCT 4.4063606275033715e-14
# MMIN 4.4063606275033715e-14
# MMAX 4.4063606275033715e-14
# CACH 4.4063606275033715e-14
# CHMIN 4.4063606275033715e-14
# CHMAX 4.4063606275033715e-14
# PRP 4.4063606275033715e-14
# Splitted node at depth 3 by feature MYCT and threshold 180
# Node 0 with 2 samples
# Node 1 with 2 samples

# %%
def predict(tree, sample):
    if(len(tree['childrens'])==0): #Leaf
        return tree['model'].predict(fix_columns(pd.get_dummies(sample),pd.get_dummies(tree['samples']).columns))
    if tree['threshold']==None: #Categorical
        found = False
        for index, child in enumerate(tree['childrens']):
            if sample[tree['split_by_feature']].values[0] == child['nominal_value']:
                print("Found")
                node = child
                found = True
                break
        if not found:
            print("Not found")
            return tree['model'].predict(fix_columns(pd.get_dummies(sample),pd.get_dummies(tree['samples']).columns))
    else: #Numeric
        if(sample[tree['split_by_feature']].values[0]>=tree['threshold']):
            node = tree['childrens'][0] #right node
        else:
            node = tree['childrens'][1]
    return predict(node, sample)

# %%
preds = [predict(tree,row.to_frame().T) for index,row in X_test.iterrows()]
mean_squared_error(preds,y_test)
# Out:
# Not found
# Found
# Found
# Found
# Found
# Found
# Found
# Not found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Not found
# Found
# Found
# Not found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Found
# Not found
# Found
# Found
# Found
# Found
# Found
# Found
# Not found
# Found
# 43974.0222939247

# %%
from sklearn.tree import DecisionTreeRegressor
regressor = DecisionTreeRegressor(random_state=0)
train_dummed = pd.get_dummies(X_train)
regressor.fit(train_dummed,y_train)
# Out:
# DecisionTreeRegressor(criterion='mse', max_depth=None, max_features=None,
#            max_leaf_nodes=None, min_impurity_decrease=0.0,
#            min_impurity_split=None, min_samples_leaf=1,
#            min_samples_split=2, min_weight_fraction_leaf=0.0,
#            presort=False, random_state=0, splitter='best')

# %%
y_1 = regressor.predict(fix_columns(pd.get_dummies(X_test), pd.get_dummies(X_train).columns))
mean_squared_error(y_1, y_test)
# Out:
# 1113.3333333333333
